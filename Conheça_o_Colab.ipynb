# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannacruz-dot/Desenvolvimento-2/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conheça o Colab

# %%
rodas = 4
peso = 4000
qtd_de_pessoas = 4

if (rodas == 2 or rodas == 3):
    print("Carteira A")

elif (rodas == 4 and qtd_de_pessoas <= 8 and peso <= 3500):
    print("Carteira B")

elif (rodas >= 4 and peso > 3500 and peso <= 6000):
    print("Carteira C")

elif (rodas >= 4 and qtd_de_pessoas > 8):
    print("Carteira D")

elif (rodas >= 4 and peso > 6000):
    print("Carteira E")
# Out:
# Carteira C
